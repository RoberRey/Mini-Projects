# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Usuario\\Desktop\\Data Science\\Kaggle\\tps-nov-2022\\notebooks'

# %%
import numpy as np
import pandas as pd

# %%
os.chdir('..')

# %%
os.listdir('data')
# Out:
# ['sample_submission.csv',
#  'submission_files',
#  'submission_try.csv',
#  'tabular-playground-series-nov-2022.zip',
#  'train_labels.csv']

# %%
data_folder = './data/'
data_submission_folder = './data/submission_files/'

# %%
files = os.listdir(data_submission_folder)

# %%
num_files = 0
preds = np.zeros(40000)
for file in files:
    num_files += 1
    data_file = pd.read_csv(f'{data_submission_folder}{file}')
    if num_files == 1:
        final_data = data_file.copy()
    else:
        final_data.loc[:,file] = data_file.pred
# Out:
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# ...
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9940/167812700.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_data.loc[:,file] = data_file.pred

# %%
final_data
# Out:
#           id      pred  0.6223807245.csv  0.6225426578.csv  0.6247722291.csv  \
# 0          0  0.709336          0.799007          0.851891          0.537158
# 1          1  0.452988          0.364453          0.567582          0.354468
# 2          2  0.675462          0.842260          0.800013          0.525229
# 3          3  0.481046          0.577118          0.683032          0.541356
# 4          4  0.957339          0.910337          0.917322          0.874487
# ...      ...       ...               ...               ...               ...
# 39995  39995  0.382515          0.288985          0.483297          0.281330
# 39996  39996  0.352498          0.300423          0.594827          0.345519
# 39997  39997  0.577554          0.673746          0.760426          0.483366
# 39998  39998  0.712353          0.791621          0.807093          0.809911
# 39999  39999  0.483215          0.535898          0.606541          0.451370
#
#        0.6253455681.csv  0.6254850917.csv  0.6255093621.csv  0.6260141578.csv  \
# 0              0.623930          0.705970          0.503437          0.633185
# 1              0.513818          0.584119          0.454809          0.238501
# 2              0.692071          0.715418          0.651008          0.609124
# 3              0.630088          0.664514          0.413373          0.508210
# 4              0.787595          0.854273          0.843846          0.876749
# ...                 ...               ...               ...               ...
# 39995          0.414223          0.463336          0.390367          0.229408
# 39996          0.488960          0.506300          0.216482          0.291425
# 39997          0.682265          0.663974          0.448841          0.537298
# 39998          0.654159          0.667119          0.497323          0.950074
# 39999          0.540206          0.578420          0.338534          0.669546
#
#        0.6263493693.csv  ...  0.7519100517.csv  0.7519556278.csv  \
# 0              0.641550  ...          0.769207          0.750250
# 1              0.472171  ...          0.640052          0.794052
# 2              0.691198  ...          0.812841          0.779859
# 3              0.526140  ...          0.824703          0.799698
# 4              0.821128  ...          0.934803          0.900150
# ...                 ...  ...               ...               ...
# 39995          0.455481  ...          0.561950          0.654353
# 39996          0.471500  ...          0.584715          0.620182
# 39997          0.575501  ...          0.739480          0.760507
# 39998          0.520980  ...          0.698287          0.713176
# 39999          0.506588  ...          0.639991          0.560201
#
#        0.7520219713.csv  0.7521219579.csv  0.7522329272.csv  0.7523602310.csv  \
# 0              0.663370          0.739333          0.822384          0.749498
# 1              0.721298          0.804369          0.620626          0.733606
# 2              0.865657          0.828493          0.763010          0.802883
# 3              0.800130          0.716604          0.603779          0.708499
# 4              0.960911          0.906037          0.961240          0.935608
# ...                 ...               ...               ...               ...
# 39995          0.614568          0.606837          0.474038          0.578634
# 39996          0.635899          0.584809          0.677014          0.617092
# 39997          0.774452          0.817324          0.802529          0.815348
# 39998          0.786973          0.778239          0.813394          0.781050
# 39999          0.559546          0.534714          0.730741          0.537760
#
#        0.7526089604.csv  0.7526999358.csv  0.7551167673.csv  0.7575039918.csv
# 0              0.729800          0.867847          0.745888             0.787
# 1              0.816942          0.814229          0.598331             0.547
# 2              0.806891          0.896058          0.855776             0.667
# 3              0.844837          0.853057          0.850657             0.622
# 4              0.889757          0.978505          0.953681             0.934
# ...                 ...               ...               ...               ...
# 39995          0.584544          0.542198          0.542056             0.266
# 39996          0.607261          0.577821          0.589929             0.725
# 39997          0.712255          0.864388          0.786978             0.572
# 39998          0.618386          0.774977          0.666404             0.641
# 39999          0.629192          0.712205          0.677456             0.575
#
# [40000 rows x 5001 columns]

# %%
train_labels = pd.read_csv(f'{data_folder}train_labels.csv')

# %%
final_data_label = final_data.merge(train_labels,how='left',on='id')

# %%
train_final = final_data_label[final_data_label.id < 20000]
test_final = final_data_label[final_data_label.id >= 20000]

# %%
X = train_final.drop(columns='label')
y = train_final.label

# %%
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split

# %%
params = {"objective": "binary",
          "boosting_type": "gbdt",
          "learning_rate": 0.03,
          "verbosity": -1,
}

# %%
from sklearn.metrics import log_loss
import optuna

# %%
def objective(trial):
    # Specify a search space using distributions across plausible values of hyperparameters.
    param_grid = {
    "objective": "binary",
    "metric": "binary_logloss",
    "verbosity": -1,
    "n_estimators": trial.suggest_categorical("n_estimators", [2000]),
    "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
    "num_leaves": trial.suggest_int("num_leaves", 20, 3000, step=20),
    "max_depth": trial.suggest_int("max_depth", 3, 12),
    "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 200, 10000, step=100),
#     "lambda_l1": trial.suggest_int("lambda_l1", 0, 100, step=5),
#     "lambda_l2": trial.suggest_int("lambda_l2", 0, 100, step=5),
    "min_gain_to_split": trial.suggest_float("min_gain_to_split", 0, 15),
    "bagging_fraction": trial.suggest_float("bagging_fraction", 0.2, 0.90, step=0.1),
    'bagging_freq': trial.suggest_int('bagging_freq', 0, 15),
    "feature_fraction": trial.suggest_float("feature_fraction", 0.2, 0.90, step=0.1),}
    
    nfolds = 5
    
    cv = StratifiedKFold(n_splits=nfolds)
    log_losses = []
    for train_index, test_index in cv.split(X, y):
        X_train, X_test = X.iloc[train_index,:], X.iloc[test_index,:]
        y_train, y_test = y[train_index], y[test_index]
        dtrain = lgb.Dataset(X_train, y_train)
        dvalid = lgb.Dataset(X_test, y_test, reference=dtrain)

        clf = lgb.train(param_grid, 
                     dtrain, 
                     num_boost_round=300, 
                     valid_sets=dvalid, 
                     verbose_eval=100,
                     early_stopping_rounds=100)

        pred = clf.predict(X_test)
        log_losses.append(log_loss(y_test, pred))

    cv_score = np.mean(log_losses)

    # Return metric of interest
    return cv_score

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)
print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
# Out:
# [I 2022-11-02 18:28:01,326] A new study created in memory with name: no-name-f41cbc1b-c782-4c90-9d1b-c76cc39a3c64
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.546867
# [200]	valid_0's binary_logloss: 0.549844
# Early stopping, best iteration is:
# [126]	valid_0's binary_logloss: 0.546359
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.551835
# Early stopping, best iteration is:
# [58]	valid_0's binary_logloss: 0.549343
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.54814
# [200]	valid_0's binary_logloss: 0.548434
# Early stopping, best iteration is:
# [124]	valid_0's binary_logloss: 0.546104
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.546168
# Early stopping, best iteration is:
# [61]	valid_0's binary_logloss: 0.545262
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.542647
# Early stopping, best iteration is:
# [46]	valid_0's binary_logloss: 0.539782
# [I 2022-11-02 18:28:57,043] Trial 0 finished with value: 0.5453700822076593 and parameters: {'n_estimators': 2000, 'learning_rate': 0.22370515183749098, 'num_leaves': 1920, 'max_depth': 6, 'min_data_in_leaf': 1800, 'min_gain_to_split': 1.3486708794342206, 'bagging_fraction': 0.4, 'bagging_freq': 10, 'feature_fraction': 0.7}. Best is trial 0 with value: 0.5453700822076593.
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.538732
# Early stopping, best iteration is:
# [47]	valid_0's binary_logloss: 0.538732
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.541606
# Early stopping, best iteration is:
# [44]	valid_0's binary_logloss: 0.541599
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.542379
# Early stopping, best iteration is:
# [47]	valid_0's binary_logloss: 0.542379
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.540416
# Early stopping, best iteration is:
# [50]	valid_0's binary_logloss: 0.540416
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.533271
# Early stopping, best iteration is:
# [60]	valid_0's binary_logloss: 0.533271
# [I 2022-11-02 18:31:26,083] Trial 1 finished with value: 0.5392793964998672 and parameters: {'n_estimators': 2000, 'learning_rate': 0.0934916317034679, 'num_leaves': 1920, 'max_depth': 11, 'min_data_in_leaf': 1000, 'min_gain_to_split': 10.823502135398481, 'bagging_fraction': 0.4, 'bagging_freq': 13, 'feature_fraction': 0.2}. Best is trial 1 with value: 0.5392793964998672.
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.693147
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.693147
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.693147
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.693147
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.693147
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.693147
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.693147
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.693147
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.693147
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.693147
# [I 2022-11-02 18:32:03,030] Trial 2 finished with value: 0.6931471805599454 and parameters: {'n_estimators': 2000, 'learning_rate': 0.1366459785974566, 'num_leaves': 2620, 'max_depth': 12, 'min_data_in_leaf': 9700, 'min_gain_to_split': 0.08544522324805626, 'bagging_fraction': 0.30000000000000004, 'bagging_freq': 15, 'feature_fraction': 0.9}. Best is trial 1 with value: 0.5392793964998672.
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.539679
# Early stopping, best iteration is:
# [52]	valid_0's binary_logloss: 0.53959
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.545615
# Early stopping, best iteration is:
# [47]	valid_0's binary_logloss: 0.545503
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.542373
# Early stopping, best iteration is:
# [43]	valid_0's binary_logloss: 0.542259
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.54183
# Early stopping, best iteration is:
# [40]	valid_0's binary_logloss: 0.541696
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.536065
# Early stopping, best iteration is:
# [36]	valid_0's binary_logloss: 0.536055
# [I 2022-11-02 18:33:18,497] Trial 3 finished with value: 0.5410206574118506 and parameters: {'n_estimators': 2000, 'learning_rate': 0.21000893311870308, 'num_leaves': 900, 'max_depth': 10, 'min_data_in_leaf': 3200, 'min_gain_to_split': 6.356618492041283, 'bagging_fraction': 0.9, 'bagging_freq': 8, 'feature_fraction': 0.8}. Best is trial 1 with value: 0.5392793964998672.
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.555593
# [200]	valid_0's binary_logloss: 0.55547
# Early stopping, best iteration is:
# [111]	valid_0's binary_logloss: 0.55547
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.55739
# Early stopping, best iteration is:
# [96]	valid_0's binary_logloss: 0.557161
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.560748
# [200]	valid_0's binary_logloss: 0.560653
# Early stopping, best iteration is:
# [101]	valid_0's binary_logloss: 0.560653
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.557718
# Early stopping, best iteration is:
# [85]	valid_0's binary_logloss: 0.557718
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.552627
# [200]	valid_0's binary_logloss: 0.55253
# Early stopping, best iteration is:
# [102]	valid_0's binary_logloss: 0.55253
# [I 2022-11-02 18:36:03,619] Trial 4 finished with value: 0.5567286178816584 and parameters: {'n_estimators': 2000, 'learning_rate': 0.11622812414649851, 'num_leaves': 2020, 'max_depth': 12, 'min_data_in_leaf': 3500, 'min_gain_to_split': 9.880260817647283, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'feature_fraction': 0.4}. Best is trial 1 with value: 0.5392793964998672.
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.693147
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.693147
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.693147
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.693147
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.693147
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.693147
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.693147
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.693147
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.693147
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.693147
# [I 2022-11-02 18:36:55,100] Trial 5 finished with value: 0.6931471805599454 and parameters: {'n_estimators': 2000, 'learning_rate': 0.25883685264373557, 'num_leaves': 880, 'max_depth': 5, 'min_data_in_leaf': 6900, 'min_gain_to_split': 9.778808680705197, 'bagging_fraction': 0.7, 'bagging_freq': 4, 'feature_fraction': 0.30000000000000004}. Best is trial 1 with value: 0.5392793964998672.
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.542234
# Early stopping, best iteration is:
# [86]	valid_0's binary_logloss: 0.54201
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.549171
# [200]	valid_0's binary_logloss: 0.548358
# [300]	valid_0's binary_logloss: 0.548839
# Early stopping, best iteration is:
# [232]	valid_0's binary_logloss: 0.546962
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.543823
# [200]	valid_0's binary_logloss: 0.544456
# Early stopping, best iteration is:
# [172]	valid_0's binary_logloss: 0.543163
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.543982
# [200]	valid_0's binary_logloss: 0.544124
# Early stopping, best iteration is:
# [144]	valid_0's binary_logloss: 0.543135
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.537979
# Early stopping, best iteration is:
# [62]	valid_0's binary_logloss: 0.537445
# [I 2022-11-02 18:38:02,856] Trial 6 finished with value: 0.542543083230614 and parameters: {'n_estimators': 2000, 'learning_rate': 0.15281043087635365, 'num_leaves': 300, 'max_depth': 8, 'min_data_in_leaf': 2100, 'min_gain_to_split': 0.5738478879305198, 'bagging_fraction': 0.5, 'bagging_freq': 3, 'feature_fraction': 0.8}. Best is trial 1 with value: 0.5392793964998672.
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.693147
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.693147
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.693147
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.693147
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.693147
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.693147
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.693147
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.693147
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.693147
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.693147
# ...
# [100]	valid_0's binary_logloss: 0.538687
# [200]	valid_0's binary_logloss: 0.53567
# Early stopping, best iteration is:
# [171]	valid_0's binary_logloss: 0.53567
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.537887
# [200]	valid_0's binary_logloss: 0.534323
# [300]	valid_0's binary_logloss: 0.534246
# Early stopping, best iteration is:
# [252]	valid_0's binary_logloss: 0.534246
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.528184
# [200]	valid_0's binary_logloss: 0.523007
# [300]	valid_0's binary_logloss: 0.523017
# Early stopping, best iteration is:
# [202]	valid_0's binary_logloss: 0.522997
# [I 2022-11-02 20:18:27,674] Trial 97 finished with value: 0.531561190952351 and parameters: {'n_estimators': 2000, 'learning_rate': 0.02143004853356642, 'num_leaves': 1340, 'max_depth': 6, 'min_data_in_leaf': 1300, 'min_gain_to_split': 14.988387985327483, 'bagging_fraction': 0.9, 'bagging_freq': 3, 'feature_fraction': 0.30000000000000004}. Best is trial 95 with value: 0.526598415877022.
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.559822
# [200]	valid_0's binary_logloss: 0.533655
# [300]	valid_0's binary_logloss: 0.528518
# [400]	valid_0's binary_logloss: 0.530352
# Early stopping, best iteration is:
# [319]	valid_0's binary_logloss: 0.528215
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.560639
# [200]	valid_0's binary_logloss: 0.535269
# [300]	valid_0's binary_logloss: 0.529562
# [400]	valid_0's binary_logloss: 0.528684
# [500]	valid_0's binary_logloss: 0.528643
# Early stopping, best iteration is:
# [432]	valid_0's binary_logloss: 0.528641
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.560865
# [200]	valid_0's binary_logloss: 0.535394
# [300]	valid_0's binary_logloss: 0.529776
# [400]	valid_0's binary_logloss: 0.528906
# [500]	valid_0's binary_logloss: 0.528778
# Early stopping, best iteration is:
# [436]	valid_0's binary_logloss: 0.528778
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.559731
# [200]	valid_0's binary_logloss: 0.53392
# [300]	valid_0's binary_logloss: 0.52819
# [400]	valid_0's binary_logloss: 0.527119
# [500]	valid_0's binary_logloss: 0.52695
# Early stopping, best iteration is:
# [483]	valid_0's binary_logloss: 0.52695
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.554601
# [200]	valid_0's binary_logloss: 0.526546
# [300]	valid_0's binary_logloss: 0.525393
# Early stopping, best iteration is:
# [256]	valid_0's binary_logloss: 0.522412
# [I 2022-11-02 20:19:38,142] Trial 98 finished with value: 0.5269995204171095 and parameters: {'n_estimators': 2000, 'learning_rate': 0.010368025718011471, 'num_leaves': 1480, 'max_depth': 6, 'min_data_in_leaf': 200, 'min_gain_to_split': 14.153256701204159, 'bagging_fraction': 0.9, 'bagging_freq': 4, 'feature_fraction': 0.2}. Best is trial 95 with value: 0.526598415877022.
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.527288
# [200]	valid_0's binary_logloss: 0.527059
# Early stopping, best iteration is:
# [125]	valid_0's binary_logloss: 0.527045
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.529299
# Early stopping, best iteration is:
# [92]	valid_0's binary_logloss: 0.529274
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.529897
# Early stopping, best iteration is:
# [91]	valid_0's binary_logloss: 0.529897
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.527682
# [200]	valid_0's binary_logloss: 0.527664
# Early stopping, best iteration is:
# [120]	valid_0's binary_logloss: 0.527664
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.519069
# Early stopping, best iteration is:
# [90]	valid_0's binary_logloss: 0.518316
# [I 2022-11-02 20:20:38,628] Trial 99 finished with value: 0.5264478253081293 and parameters: {'n_estimators': 2000, 'learning_rate': 0.04367959535512664, 'num_leaves': 1400, 'max_depth': 5, 'min_data_in_leaf': 400, 'min_gain_to_split': 12.924046793663218, 'bagging_fraction': 0.9, 'bagging_freq': 3, 'feature_fraction': 0.30000000000000004}. Best is trial 99 with value: 0.5264478253081293.
# Number of finished trials: 100
# Best trial: {'n_estimators': 2000, 'learning_rate': 0.04367959535512664, 'num_leaves': 1400, 'max_depth': 5, 'min_data_in_leaf': 400, 'min_gain_to_split': 12.924046793663218, 'bagging_fraction': 0.9, 'bagging_freq': 3, 'feature_fraction': 0.30000000000000004}

# %%
# 250

# %%
nfolds = 5
cv = StratifiedKFold(n_splits=nfolds)
cv_pred = np.zeros(20000)

for train_index, test_index in cv.split(X, y):
    X_train, X_test = X.iloc[train_index,:], X.iloc[test_index,:]
    y_train, y_test = y[train_index], y[test_index]
    dtrain = lgb.Dataset(X_train, y_train)
    dvalid = lgb.Dataset(X_test, y_test, reference=dtrain)
    
    clf = lgb.train(params, 
                 dtrain, 
                 num_boost_round=300, 
                 valid_sets=dvalid, 
                 verbose_eval=100,
                 early_stopping_rounds=100)
    
    cv_pred += clf.predict(test_final.drop(columns='label'), num_iteration=clf.best_iteration)
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.786724
# Early stopping, best iteration is:
# [33]	valid_0's binary_logloss: 0.580611
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.53036
# [200]	valid_0's binary_logloss: 0.530315
# Early stopping, best iteration is:
# [132]	valid_0's binary_logloss: 0.529731
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.529243
# [200]	valid_0's binary_logloss: 0.529369
# Early stopping, best iteration is:
# [118]	valid_0's binary_logloss: 0.528383
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.52772
# [200]	valid_0's binary_logloss: 0.52671
# [300]	valid_0's binary_logloss: 0.530037
# Did not meet early stopping. Best iteration is:
# [205]	valid_0's binary_logloss: 0.526623
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\Usuario\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.964992
# Early stopping, best iteration is:
# [30]	valid_0's binary_logloss: 0.633284
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9940/1708568949.py in <module>
#      19 #     cv_train[validate] += clf.predict(X_validate)
#      20
# ---> 21 cv_pred /= NFOLDS
#      22 # final_cv_train += cv_train
#      23 # final_cv_pred += cv_pred
#
# NameError: name 'NFOLDS' is not defined

# %%
cv_pred /= nfolds

# %%
cv_pred
# Out:
# array([0.54497295, 0.67398549, 0.28129815, ..., 0.54809505, 0.53678692,
#        0.42687255])

# %%
# y_pred = clf.predict(test_final.drop(columns='label'))

# %%
# y_pred

# %%
submission = pd.read_csv(f'{data_folder}sample_submission.csv')

# %%
submission.pred = cv_pred

# %%
submission.to_csv(f'{data_folder}submission_try.csv', index=False)
