# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Usuario\\Desktop\\Data Science\\Kaggle\\tps-nov-2022\\notebooks'

# %%
import numpy as np
import pandas as pd

# %%
os.chdir('..')

# %%
os.listdir('data')
# Out:
# ['sample_submission.csv',
#  'submission_files',
#  'tabular-playground-series-nov-2022.zip',
#  'train_labels.csv']

# %%
data_folder = './data/'
data_submission_folder = './data/submission_files/'

# %%
os.listdir(data_submission_folder)
# Out:
# ['0.6222863195.csv',
#  '0.6223807245.csv',
#  '0.6225426578.csv',
#  '0.6247722291.csv',
#  '0.6253455681.csv',
#  '0.6254850917.csv',
#  '0.6255093621.csv',
#  '0.6260141578.csv',
#  '0.6263493693.csv',
#  '0.6272779211.csv',
#  '0.6272932068.csv',
#  '0.6278191266.csv',
#  '0.6286579774.csv',
#  '0.6288297558.csv',
#  '0.6288608516.csv',
#  '0.6294457895.csv',
#  '0.6297384065.csv',
#  '0.6301504673.csv',
#  '0.6312756578.csv',
#  '0.6321136145.csv',
#  '0.6329173956.csv',
#  '0.6329211291.csv',
#  '0.6335286032.csv',
#  '0.6338206806.csv',
#  '0.6343392765.csv',
#  '0.6343846561.csv',
#  '0.6349644082.csv',
#  '0.6350090257.csv',
#  '0.6362728614.csv',
#  '0.6363549073.csv',
#  '0.6371788217.csv',
#  '0.6372032593.csv',
#  '0.6372037651.csv',
#  '0.6375467640.csv',
#  '0.6388901165.csv',
#  '0.6389095301.csv',
#  '0.6396620930.csv',
#  '0.6398920868.csv',
#  '0.6404491258.csv',
#  '0.6407502338.csv',
#  '0.6419100341.csv',
#  '0.6419834632.csv',
#  '0.6426110725.csv',
# ...

# %%
data_try = pd.read_csv(f'{data_submission_folder}0.6222863195.csv')

# %%
data_try
# Out:
#           id      pred
# 0          0  0.709336
# 1          1  0.452988
# 2          2  0.675462
# 3          3  0.481046
# 4          4  0.957339
# ...      ...       ...
# 39995  39995  0.382515
# 39996  39996  0.352498
# 39997  39997  0.577554
# 39998  39998  0.712353
# 39999  39999  0.483215
#
# [40000 rows x 2 columns]

# %%
data_submission = pd.read_csv(f'{data_folder}sample_submission.csv')

# %%
submission = data_try[data_try.id >= 20000]

# %%
submission.to_csv(f'{data_folder}submission_try.csv', index=False)
